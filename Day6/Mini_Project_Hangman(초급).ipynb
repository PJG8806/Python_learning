# %% [markdown]
# ## Mini project [행맨 게임 제작]
#
# #### 과제 설명
#
# 이번 개발 주제는 '행맨' 게임이구요.
#
# 행맨 게임은 아주 유명한 단어 퀴즈 프로그램이예요
#
# 어떤 단어가 주어지면 그 단어의 길이만큼 빈 칸(밑줄) 이 주어지고
# 플레이어는 알파벳을 하나씩 얘기하면서 단어를 추측해요!
#
# 7번 틀리게 되면 게임이 끝납니다. 🥲

# %% [markdown]
# ---

# %% [markdown]
# #### 예시를 들어볼께요!!
#
# 만약 E 가 단어에 포함돼있다면, 해당하는 위치에 E 를 표시해줍니다
#
# _ _ _ _ E E
# 이렇게 되겠네요.
#
# 이번에는 A를 해볼께요
# A 는 포함되지 않으므로 기회가 줄어들고 지금까지 맞힌 내용 그대로 출력합니다.
#
# _ _ _ _ E E
# 변화가 없지요.
#
# 이번에는 C 를 해봅시다.
#
# 그럼
# C _ _ _ E E
#
# 다음에는 F 를
# C _ F F E E
#
# 마지막으로 O 를 해보면
# C O F F E E 로 게임은 성공으로 끝나게 됩니다.

# %% [markdown]
# ---

# %% [markdown]
# ## 본격적인 행맨 게임 규칙 설명
#
# - words 리스트에 추가된 단어들을 사용해주세요
#   - words = ["apple", "banana", "orange", "grape", "lemon"]
#
# - 단어의 길이에 맞게 밑줄을 출력해주세요
#   (예)banana의 경우 _ _ _ _ _ _
#
# - 사용자부터 1글자씩 입력을 받되,
#    - 단어에 입력값이 포함되면 "단어를 맞추셨군요. 더 힘내봐요"라고 출력해주세요"
#    - 단어에 입력값이 포함되어 있지 않다면 "틀렸습니다. 남은 시도 횟수 "란 메시지와 함꼐 남은 횟수를 출력해주세요
#
# - 매번 입력을 받을 때마다 현재까지 맞힌 글자들 표시(맞히면 글자는 밑줄 출력)
#     - 예) a 입력 시 : a _ _ _ _
#           p 입력 시 : a p p _ _
#           c 입력 시 : a p p _ _
#
# - 모든 단어를 맞췄을 경우 "축하합니다! 단어를 맞추셨습니다"와 시도 횟수를 출력해주세요
#
#
# 행맨은 정말 유명 게임으로 찾아볼 수 있는 자료들이 많습니다.
# 문제가 어려우신 경우 구글링 통해 문제를 해결해보세요.

# %%
# 기본 라이브러리라 파이썬 설치시 자동으로 설치됩니다!
# random 모듈은 랜덤한 숫자를 생성할 때 사용합니다.
import random

# 게임에 사용될 단어 목록
words = ["apple", "banana", "orange", "grape", "lemon"]

# 행맨 그림
hangman_pics = [
    """
     ------
     |    |
     |
     |
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |    |
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|\
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|\
     |   /
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|\
     |   / \
     |
    ---""",
]


class HangmanGame:
    def __init__(self):
        """
        - 랜덤으로 단어를 선택하여 self.word에 저장        
        - 추측된 글자를 저장할 집합 self.guesses를 초기화
        - 남은 시도 횟수를 6으로 설정
        """
        self.word = words[random.randint(0,len(words)-1)]
        self.guesses = "".join(["_" for i in range(len(self.word))])
        self.attempts = 6

    def display(self):
        """
        - 현재까지 맞춘 글자를 표시하는 문자열 result를 초기화
        - self.word의 각 글자를 순회
            - 만약 그 글자가 self.guesses에 있으면 그대로 표시
            - 없으면 '_'로 표시
        - 완성된 result 문자열을 반환
        """        
        self.result = "".join(["_" for i in range(len(self.word))])      
        for i in range(len(self.word)):
                if self.word[i] == self.guesses[i]:
                    self.tmp_result = list(self.result)
                    self.tmp_result[i] = self.guesses[i]
                    self.result = "".join(self.tmp_result)
        return self.result        

    def play(self):
        """
        - 게임을 시작 (남은 시도 횟수 self.attempts가 0보다 클 동안 반복)
            - 현재 행맨 그림을 출력 (틀린 횟수에 따라)
            - 현재까지의 단어 상태를 출력
            - 사용자로부터 알파벳을 입력받음
            - 입력받은 알파벳이 이미 추측된 경우 알림
            - 새로운 추측이라면:
                - 단어에 포함되면 self.guesses에 추가하고 "단어를 맞추셨군요. 더 힘내봐요!" 출력
                    - 단어의 모든 글자를 맞췄는지 확인하고, 맞췄으면 축하 메시지 후 종료
                - 단어에 포함되지 않으면 시도 횟수를 1 감소시키고 틀렸다는 메시지 출력
            - 반복문 종료 조건: 시도 횟수가 0
                - 게임 오버 메시지와 정답 출력
        """
        while self.attempts > 0:
            print(hangman_pics[-self.attempts])
            print(self.guesses)
            self.letter = input("알파벳 하나를 입력하세요")[0]
            if self.letter in self.guesses:
                print("이미 추축된 알파벳입니다.")
                continue
            else:
                self.guesses = self.guesses.replace("_",self.letter)             
                self.guesses = self.display()   
                if self.letter in self.guesses:
                    if self.guesses == self.word:
                        print("축하합니다 다 맞췄습니다.")   
                        break
                    else:
                        print("단어를 맞추셨군요. 더 힘내봐요!")
                else:
                    self.attempts -= 1
                    print("틀렸습니다.")     
        print("게임 오버")

if __name__ == "__main__":
    game = HangmanGame()
    game.play()
# Out:
#      ------
#      |    |
#      |    O
#      |
#      |
#      |
#     ---
# _____
# 단어를 맞추셨군요. 더 힘내봐요!
#
#      ------
#      |    |
#      |    O
#      |
#      |
#      |
#     ---
# __a__
# 틀렸습니다.
#
#      ------
#      |    |
#      |    O
#      |    |
#      |
#      |
#     ---
# __a__
# 틀렸습니다.
#
#      ------
#      |    |
#      |    O
#      |   /|
#      |
#      |
#     ---
# __a__
# 단어를 맞추셨군요. 더 힘내봐요!
#
#      ------
#      |    |
#      |    O
#      |   /|
#      |
#      |
#     ---
# __a_e
# 틀렸습니다.
#
#      ------
#      |    |
#      |    O
#      |   /|     |
#      |
#     ---
# __a_e
# 이미 추축된 알파벳입니다.
#
#      ------
#      |    |
#      |    O
#      |   /|     |
#      |
#     ---
# __a_e
# 틀렸습니다.
#
#      ------
#      |    |
#      |    O
#      |   /|     |   /
#      |
#     ---
# __a_e
# 틀렸습니다.
#
#      ------
#      |    |
#      |    O
#      |   /|     |   /      |
#     ---
# __a_e
# 단어를 맞추셨군요. 더 힘내봐요!
#
#      ------
#      |    |
#      |    O
#      |   /|     |   /      |
#     ---
# g_a_e
# 틀렸습니다.
# 게임 오버
